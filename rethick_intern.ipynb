# %% [markdown]
# <a href="https://colab.research.google.com/github/Rethick11/Ensemble_Implementation/blob/master/rethick_intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt

# %%
data = load_iris()
X_train, X_test, y_train, y_test  = train_test_split(data.data, data.target ,test_size = 0.3,random_state = 42)

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred = tree_model.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
# tree.plot_tree(tree_model,feature_names=data.feature_names,class_names=data.target_names)
fig = plt.figure(figsize=(25,20))
tree.plot_tree(tree_model, 
                   feature_names=data.feature_names,  
                   class_names=data.target_names,
                   filled=True)
# Out:
# [Text(429.2307692307692, 1009.5428571428572, 'petal length (cm) <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [31, 37, 37]\nclass = versicolor'),
#  Text(321.9230769230769, 854.2285714285715, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = setosa'),
#  Text(536.5384615384615, 854.2285714285715, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]\nclass = versicolor'),
#  Text(214.6153846153846, 698.9142857142858, 'petal width (cm) <= 1.6\ngini = 0.059\nsamples = 33\nvalue = [0, 32, 1]\nclass = versicolor'),
#  Text(107.3076923076923, 543.6, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(321.9230769230769, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(858.4615384615385, 698.9142857142858, 'petal width (cm) <= 1.75\ngini = 0.214\nsamples = 41\nvalue = [0, 5, 36]\nclass = virginica'),
#  Text(536.5384615384615, 543.6, 'petal length (cm) <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(429.2307692307692, 388.28571428571433, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(643.8461538461538, 388.28571428571433, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(536.5384615384615, 232.97142857142865, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(751.1538461538462, 232.97142857142865, 'petal length (cm) <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(643.8461538461538, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(858.4615384615385, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(1180.3846153846155, 543.6, 'petal length (cm) <= 4.85\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32]\nclass = virginica'),
#  Text(1073.076923076923, 388.28571428571433, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(965.7692307692307, 232.97142857142865, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(1180.3846153846155, 232.97142857142865, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(1287.6923076923076, 388.28571428571433, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]\nclass = virginica')]
